# %%
import pandas as pd

# %%
csv_file = 'C:/Users/Ilechie Peniel/Downloads/police_killings.csv'
police_killings = pd.read_csv(csv_file)

# %%
police_killings.head()
# Out:
#              Victim's name Victim's age Victim's gender Victim's race  \
# 0           Eric M. Tellez           28            Male         White
# 1  Name withheld by police          NaN            Male  Unknown race
# 2             Terry Hudson           57            Male         Black
# 3           Malik Williams           23            Male         Black
# 4        Frederick Perkins           37            Male         Black
#
#                               URL of image of victim  \
# 0  https://fatalencounters.org/wp-content/uploads...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Date of Incident (month/day/year) Street Address of Incident          City  \
# 0                        31/12/2019                 Broad St.          Globe
# ...

# %%
police_killings = police_killings.dropna(axis=1, how='all')
police_killings = police_killings.dropna(axis=0, how='all')

# %%
police_killings.shape
# Out:
# (7663, 27)

# %%
police_killings.head()
# Out:
#              Victim's name Victim's age Victim's gender Victim's race  \
# 0           Eric M. Tellez           28            Male         White
# 1  Name withheld by police          NaN            Male  Unknown race
# 2             Terry Hudson           57            Male         Black
# 3           Malik Williams           23            Male         Black
# 4        Frederick Perkins           37            Male         Black
#
#                               URL of image of victim  \
# 0  https://fatalencounters.org/wp-content/uploads...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Date of Incident (month/day/year) Street Address of Incident          City  \
# 0                        31/12/2019                 Broad St.          Globe
# ...

# %%
police_killings.drop(columns=['URL of image of victim', 'Street Address of Incident', "Symptoms of mental illness?", "A brief description of the circumstances surrounding the death", "ID", "WaPo ID (If included in WaPo database)"])
# Out:
#                 Victim's name Victim's age Victim's gender Victim's race  \
# 0              Eric M. Tellez           28            Male         White
# 1     Name withheld by police          NaN            Male  Unknown race
# 2                Terry Hudson           57            Male         Black
# 3              Malik Williams           23            Male         Black
# 4           Frederick Perkins           37            Male         Black
# ...                       ...          ...             ...           ...
# 7658              Mark Chavez           49            Male      Hispanic
# 7659               Tyree Bell           31            Male         Black
# 7660      Christopher Tavares           21            Male      Hispanic
# 7661        Andrew L. Closson           21            Male         White
# 7662            Andrew Layton           26            Male         White
#
#      Date of Incident (month/day/year)          City State  Zipcode  \
# ...

# %%
police_killings["Victim's race"].unique()
# Out:
# array(['White', 'Unknown race', 'Black', 'Hispanic', 'Pacific Islander',
#        'Asian', 'Native American', 'Unknown Race'], dtype=object)

# %%
police_killings["Victim's race"].value_counts().to_frame()
# Out:
#                   Victim's race
# White                      3378
# Black                      1944
# Hispanic                   1335
# Unknown race                670
# Asian                       118
# Native American             112
# Unknown Race                 64
# Pacific Islander             42

# %%
missing_data = police_killings.isnull()
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Victim's name
# False    7663
# Name: Victim's name, dtype: int64
#
# Victim's age
# False    7596
# True       67
# Name: Victim's age, dtype: int64
#
# Victim's gender
# False    7655
# True        8
# Name: Victim's gender, dtype: int64
#
# Victim's race
# False    7663
# Name: Victim's race, dtype: int64
#
# URL of image of victim
# False    4200
# True     3463
# Name: URL of image of victim, dtype: int64
#
# Date of Incident (month/day/year)
# False    7663
# Name: Date of Incident (month/day/year), dtype: int64
#
# Street Address of Incident
# False    7580
# True       83
# Name: Street Address of Incident, dtype: int64
#
# City
# False    7657
# True        6
# Name: City, dtype: int64
#
# State
# False    7663
# Name: State, dtype: int64
#
# Zipcode
# False    7624
# True       39
# Name: Zipcode, dtype: int64
#
# County
# False    7648
# True       15
# Name: County, dtype: int64
#
# Agency responsible for death
# False    7647
# True       16
# ...

# %%
police_killings.dtypes
# Out:
# Victim's name              object
# Victim's age               object
# Victim's gender            object
# Victim's race              object
# URL of image of victim     object
#                            ...
# Unnamed: 61               float64
# Unnamed: 62               float64
# Unnamed: 63               float64
# Unnamed: 64               float64
# Unnamed: 65               float64
# Length: 66, dtype: object

# %%
police_killings.dropna(axis=1, how='all')
# Out:
#                 Victim's name Victim's age Victim's gender Victim's race  \
# 0              Eric M. Tellez           28            Male         White
# 1     Name withheld by police          NaN            Male  Unknown race
# 2                Terry Hudson           57            Male         Black
# 3              Malik Williams           23            Male         Black
# 4           Frederick Perkins           37            Male         Black
# ...                       ...          ...             ...           ...
# 7902                      NaN          NaN             NaN           NaN
# 7903                      NaN          NaN             NaN           NaN
# 7904                      NaN          NaN             NaN           NaN
# 7905                      NaN          NaN             NaN           NaN
# 7906                      NaN          NaN             NaN           NaN
#
#                                  URL of image of victim  \
# ...
